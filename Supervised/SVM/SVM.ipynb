# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# Step 1: Create Dataset 
data = {
    'Age':[22,25,30,35,40,28],
    'Salary':[25000,30000,50000,65000,80000,48000],
    'Purchased':[0,0,1,1,1,0]
}

df = pd.DataFrame(data)

# Step 2: Features and Target 
X = df[['Age', 'Salary']]
y = df['Purchased']

# Step 3: Feature Scaling 
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 4: Train SVM Model
model = SVC(kernel='linear')
model.fit(X_scaled,y)

# Step 5: Prediction 
new_customer = scaler.transform([[32,60000]])
prediction = model.predict(new_customer)

print("Prediction (1=Buy, 0=Not Buy):", prediction[0])

# Step 6:
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 25
#      23 # Step 4: Train SVM Model
#      24 model = SVC(kernel='linear')
# ---> 25 model.fot(X_scaled,y)
#      27 # Step 5: Prediction
#      28 new_customer = scaler.transform([[32,60000]])
#
# AttributeError: 'SVC' object has no attribute 'fot'
