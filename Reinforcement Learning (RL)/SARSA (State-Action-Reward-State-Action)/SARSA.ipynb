# %%
import numpy as np 

Q = np.zeros((5,2))

alpha = 0.8
gamma = 0.9

for i in range(100):

    s = np.random.randint(5)
    a = np.random.randint(2)

    r = np.random.randint(2)
    s2 = np.random.randint(5)
    a2 = np.random.randint(2)

    Q[s,a] = Q[s
