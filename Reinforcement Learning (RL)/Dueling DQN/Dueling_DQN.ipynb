# %%
import tensorflow as tf
from tensorflow.keras import layers, models

state_size = 4
action_size = 2

inputs = layers.Input(shape=(state_size,))

dense = layers.Dense(24, activation='relu')(inputs)

value = layers.Dense(1)(dense)
advantage = layers.Dense(action_size)(dense)

output = value + (advantage - tf.reduce_mean(advantage))

model = models.Model(inputs=inputs, outputs=output)

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_155/2469588470.py in <cell line: 0>()
#      12 advantage = layers.Dense(action_size)(dense)
#      13
# ---> 14 output = value + (advantage - tf.reduce_mean(advantage))
#      15
#      16 model = models.Model(inputs=inputs, outputs=output)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/weak_tensor_ops.py in wrapper(*args, **kwargs)
#      86   def wrapper(*args, **kwargs):
#      87     if not ops.is_auto_dtype_conversion_enabled():
# ---> 88       return op(*args, **kwargs)
#      89     bound_arguments = signature.bind(*args, **kwargs)
#      90     bound_arguments.apply_defaults()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
# ...
