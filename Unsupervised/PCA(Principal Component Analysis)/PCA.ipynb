# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler 

# Dataset 
data = {
    'Height':[170,180,175,160,165],
    'Weight':[65,75,70,55,60],
    'Age':[25,30,28,22,24]
}

df = pd.DataFrame(data)

# Feature scaling 
scaler = StandardScaler()
X_scaled = scaler.fit_transfrom(df)

# PCA 
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print(x_pca)

# Visualization 
plt.scatter(X_pca[:,0], X_pca[:,1])
plt.xlabel("Principal Component 1")
plt.yalbel("Principal Compenent 2")
plt.title("PCA Visualization")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 17
#      15 # Feature scaling
#      16 scaler = StandardScaler()
# ---> 17 X_scaled = scaler.fit_transfrom(df)
#      19 # PCA
#      20 pca = PCA(n_components=2)
#
# AttributeError: 'StandardScaler' object has no attribute 'fit_transfrom'
