# %%
import numpy as np 
from sklearn.semi_supervised import SelfTrainingClassifier 
from sklearn.tree import DecisionTreeClassifier

X = np.array([
    [1,2],
    [2,3],
    [3,4],
    [6,7],
    [7,8],
    [8,9]
])

y = np.array([0,0,-1,1,1,-1])  # -1 = unlabeled 

base_model = DecisionTreeClassifier()

model = SelfTrainingclassifier(base_model)
model.fit(X,y)

print(model.predict(X))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 18
#      14 y = np.array([0,0,-1,1,1,-1])  # -1 = unlabeled
#      16 base_model = DecisionTreeClassifier()
# ---> 18 model = SelfTrainingclassifier(base_model)
#      19 model.fit(X,y)
#      21 print(model.predict(X))
#
# NameError: name 'SelfTrainingclassifier' is not defined
