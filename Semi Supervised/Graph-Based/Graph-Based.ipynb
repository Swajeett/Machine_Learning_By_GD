# %%
import numpy as np 
from sklearn.semi_supervised import LabelPropagation

# Dataset 
X = np.array([
    [1,2],
    [2,3],
    [3,4],
    [6,7],
    [7,8],
    [8,9]
])

# -1 means unlabeled 
y = np.array([0,0,-1,1,1,-1])

# Graph based model
model = LabelPropagation(kernel='knn', n
