# %%
import numpy as np 
from sklearn.semi_supervised import LabelSpreading

X = np.array([
    [1,2],
    [2,3],
    [3,4],
    [6,7],
    [7,8],
    [8,9]
])

y = np.array([0,0,-1,1,1,-1])

model = LabelSpreading()
model.fit(X,y)

print(model.trans
